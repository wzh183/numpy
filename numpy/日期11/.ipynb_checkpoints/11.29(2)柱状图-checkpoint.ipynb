# %%
from matplotlib import pylab as plt
import numpy as np

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.dpi']=100
plt.rcParams['figure.figsize'] = (5,3)

# %%
# 直方图
# 使用nump随机生成300个随机数字
# x_value = np.random.randint(140,180,300)
# plt.xticks = bins_limit
# num,bins_limit,patches = plt.hist(x_value,bins=10,edgecolor='pink')
# plt.title('数据统计')
# plt.xlabel('身高')
# plt.ylabel('比率')
# plt.xticks(bins_limit)
# print(num)
# print(bins_limit)
# print(patches)
# for i in patches:
#     print(i)

# %%
x = np.random.randint(160,190,300)
# 添加图名
plt.title('身高图')
plt.xlabel('身高')
# 绘制直方图  ------有返回值(3个)
num,li,patches = plt.hist(x,bins=10,edgecolor='white')
print('num 是分组区间对应的频率',num)
print('bins_limit 是分组时的分隔值',bins_limit)
print('patches 是直方图的列表对象',type(patches))
for i in patches:
    print(i)
plt.xticks(li,rotation=45)
# Out:
# num 是分组区间对应的频率 [20. 30. 35. 26. 32. 34. 28. 34. 30. 31.]
# bins_limit 是分组时的分隔值 [140.  143.9 147.8 151.7 155.6 159.5 163.4 167.3 171.2 175.1 179. ]
# patches 是直方图的列表对象 <class 'matplotlib.container.BarContainer'>
# Rectangle(xy=(160, 0), width=2.9, height=20, angle=0)
# Rectangle(xy=(162.9, 0), width=2.9, height=30, angle=0)
# Rectangle(xy=(165.8, 0), width=2.9, height=35, angle=0)
# Rectangle(xy=(168.7, 0), width=2.9, height=26, angle=0)
# Rectangle(xy=(171.6, 0), width=2.9, height=32, angle=0)
# Rectangle(xy=(174.5, 0), width=2.9, height=34, angle=0)
# Rectangle(xy=(177.4, 0), width=2.9, height=28, angle=0)
# Rectangle(xy=(180.3, 0), width=2.9, height=34, angle=0)
# Rectangle(xy=(183.2, 0), width=2.9, height=30, angle=0)
# Rectangle(xy=(186.1, 0), width=2.9, height=31, angle=0)
# ([<matplotlib.axis.XTick at 0x22c05cc9970>,
#   <matplotlib.axis.XTick at 0x22c0806cc10>,
#   <matplotlib.axis.XTick at 0x22c07ae6670>,
#   <matplotlib.axis.XTick at 0x22c07ab8eb0>,
#   <matplotlib.axis.XTick at 0x22c07bf2ca0>,
#   <matplotlib.axis.XTick at 0x22c07aa2490>,
#   <matplotlib.axis.XTick at 0x22c07aae250>,
#   <matplotlib.axis.XTick at 0x22c07aa41f0>,
#   <matplotlib.axis.XTick at 0x22c07a94e20>,
#   <matplotlib.axis.XTick at 0x22c07ac4a90>,
#   <matplotlib.axis.XTick at 0x22c07abc8b0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
x_value = np.random .randint(140,180,300)

# 创建画布
fig,ax = plt.subplots()
num,bins_limit,pathches = plt.hist(x_value,bins=10,edgecolor='r')
plt.xticks(bins_limit,rotation=45)
print(num)
# num 的数量是10,bins_limit 是11,需要截取
print(bins_limit[:-1])
# 曲线图
ax.plot(bins_limit[:-1],num,'--',marker='o')
plt.xticks(bins_limit,rotation=45)
# Out:
# [36. 35. 23. 18. 32. 26. 38. 31. 31. 30.]
# [140.  143.9 147.8 151.7 155.6 159.5 163.4 167.3 171.2 175.1]
# ([<matplotlib.axis.XTick at 0x22c077306d0>,
#   <matplotlib.axis.XTick at 0x22c07a57af0>,
#   <matplotlib.axis.XTick at 0x22c07a577c0>,
#   <matplotlib.axis.XTick at 0x22c06da4b20>,
#   <matplotlib.axis.XTick at 0x22c05c93d00>,
#   <matplotlib.axis.XTick at 0x22c05ca0f40>,
#   <matplotlib.axis.XTick at 0x22c05ca08b0>,
#   <matplotlib.axis.XTick at 0x22c05bb9430>,
#   <matplotlib.axis.XTick at 0x22c05bb9190>,
#   <matplotlib.axis.XTick at 0x22c05c93310>,
#   <matplotlib.axis.XTick at 0x22c05c912b0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig,ax=plt.subplots()
x = np.random.normal(100,20,100)
bins=[50,60,70,90,100,110,140,150]
ax.hist(x,bins,color='r',rwidth=0.5)
ax.set_title('不等距分组')
# Out:
# Text(0.5, 1.0, '不等距分组')
