# %%
from matplotlib import pylab as plt
import numpy as np

# %%
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.rcParams['figure.dpi']=100
plt.rcParams['figure.figsize'] = (5,3)

# %%
countries = ['挪威','德国', '中国','美国','瑞典']
# 金牌个数
gold_medal = [16,12,9,8,8]
silver_medal = [8,10,4,10,5]
bronze_medal = [13,5,2,7,5]
all_medal = [37,27,15,25,18]
plt.barh(countries,width=silver_medal,color='silver')
# Out:
# <BarContainer object of 5 artists>

# %%
movie = ['新蝙蝠侠','狙击手','奇迹笨小孩']
real_day1 = np.array([4053,2548,1543])
real_day2 = np.array([7840,4013,2421])
real_day3 = np.array([8080,3673,1342])
# 确定距离
left_day2 = real_day1
left_day3 = real_day1 + real_day2
# 设置高度
height = 0.2
# 绘制图形
plt.barh(movie,real_day1,height=height,label='第一天')
plt.barh(movie,real_day2,left=left_day2,height=height,label='第二天')
plt.barh(movie,real_day3,left=left_day3,height=height,label='第三天')
# 图例
plt.legend()
# 显示文本值 计算宽度值 y轴为值
sum_data = real_day1+real_day2+real_day3
for i in range(len(movie)):
    plt.text(sum_data[i],movie[i],sum_data[i],va='center',ha='left')

# %%
movie = ['新蝙蝠侠','狙击手','奇迹笨小孩']
real_day1 = np.array([4053,2548,1543])
real_day2 = np.array([7840,4013,2421])
real_day3 = np.array([8080,3673,1342])
num_y = np.arange(len(movie))
# 设置高度
height=0.2
# 计算每一个起始高度
movie1_start_y = num_y
movie2_start_y = num_y + height
movie3_start_y = num_y + height*2
# 绘制
plt.barh(movie1_start_y,real_day1,height=height)
plt.barh(movie2_start_y,real_day2,height=height)
plt.barh(movie3_start_y,real_day3,height=height)
# 将y轴转化为原来
plt.yticks(num_y+height,movie)
# Out:
# ([<matplotlib.axis.YTick at 0x2bf4bc56a90>,
# ...
#  [Text(0, 0.2, '新蝙蝠侠'), Text(0, 1.2, '狙击手'), Text(0, 2.2, '奇迹笨小孩')])

# %%
countries = ['挪威','德国', '中国','美国','瑞典']
# 金牌个数
gold_medal = [16,12,9,8,8]
silver_medal = [8,10,4,10,5]
bronze_medal = [13,5,2,7,5]


num_y = np.arange(len(countries))
# 设置高度
height=0.2
# 计算每一个起始高度
countries1_start_y = num_y
countries2_start_y = num_y + height
countries3_start_y = num_y + height*2
# 绘制
plt.barh(countries1_start_y,gold_medal,height=height,color='gold')
plt.barh(countries2_start_y,silver_medal,height=height,color='silver')
plt.barh(countries3_start_y,bronze_medal,height=height,color='brown')
# 将y轴转化为原来
plt.yticks(num_y+height,countries)


for i in range(len(countries)):
    plt.text(gold_medal[i],countries1_start_y[i],gold_medal[i],va='center',ha='left')
    plt.text(silver_medal[i],countries2_start_y[i],silver_medal[i],va='center',ha='left')
    plt.text(bronze_medal[i],countries3_start_y[i],bronze_medal[i],va='center',ha='left')

# %%
countries = ['挪威','德国', '中国','美国','瑞典']
# 金牌个数
gold_medal = np.array([16,12,9,8,8])
silver_medal = np.array([8,10,4,10,5])
bronze_medal = np.array([13,5,2,7,5])


# 确定距离
left_2 = gold_medal
left_3 = gold_medal + silver_medal
# 设置高度
height = 0.2
# 绘制图形
plt.barh(countries,gold_medal,height=height,label='金',color='gold')
plt.barh(countries,silver_medal,left=left_2,height=height,label='银',color='silver')
plt.barh(countries,bronze_medal,left=left_3,height=height,label='铜',color='brown')
# 图例
plt.legend()
# 显示文本值 计算宽度值 y轴为值
sum_data = gold_medal+silver_medal+bronze_medal
for i in range(len(countries)):
    plt.text(sum_data[i],countries[i],sum_data[i],va='center',ha='left')
